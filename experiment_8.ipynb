# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


data = {
    'Age': [18, 19, 20, 21, 22],
    'Marks': [85, 90, 88, 92, 95],
    'Height': [5.4, 5.6, 5.5, 5.7, 5.8],
    'Weight': [55, 60, 58, 62, 65]
}

df = pd.DataFrame(data)

print("Original Dataset:\n")
print(df)


scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

print("\nStandardized Data:\n")
print(scaled_data)


pca = PCA(n_components=2)
pca_data = pca.fit_transform(scaled_data)


pca_df = pd.DataFrame(pca_data, columns=['PC1', 'PC2'])

print("\nDataset after applying PCA:\n")
print(pca_df)


print("\nExplained Variance Ratio:")
print(pca.explained_variance_ratio_)
# Out:
# Original Dataset:
#
#    Age  Marks  Height  Weight
# 0   18     85     5.4      55
# 1   19     90     5.6      60
# 2   20     88     5.5      58
# 3   21     92     5.7      62
# 4   22     95     5.8      65
#
# Standardized Data:
#
# [[-1.41421356 -1.46805055 -1.41421356 -1.46805055]
#  [-0.70710678  0.          0.          0.        ]
#  [ 0.         -0.58722022 -0.70710678 -0.58722022]
#  [ 0.70710678  0.58722022  0.70710678  0.58722022]
#  [ 1.41421356  1.46805055  1.41421356  1.46805055]]
#
# Dataset after applying PCA:
#
#         PC1       PC2
# 0 -2.882365 -0.030903
# 1 -0.340860 -0.618044
# 2 -0.951593  0.529226
# 3  1.292453  0.088818
# 4  2.882365  0.030903
#
# Explained Variance Ratio:
# [0.96541032 0.03359287]
