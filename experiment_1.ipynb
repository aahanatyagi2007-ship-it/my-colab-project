# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error


data = {
    'Experience': [1, 2, 3, 4, 5],
    'Salary': [15000, 20000, 25000, 30000, 35000]
}

df = pd.DataFrame(data)


X = df[['Experience']]
y = df['Salary']


model = LinearRegression()


model.fit(X, y)


predictions = model.predict(X)


mae = mean_absolute_error(y, predictions)
mse = mean_squared_error(y, predictions)

print("Predictions:", predictions)
print("MAE:", mae)
print("MSE:", mse)
# Out:
# Predictions: [15000. 20000. 25000. 30000. 35000.]
# MAE: 0.0
# MSE: 0.0

# %%
# !git config --global user.name "aahanatyagi2007-ship-it"
# !git config --global user.email "aahanatyagi2007@gmail.com"

# %%
# %cd /content
# !git clone https://github.com/aahanatyagi2007-ship-it/my-colab-project.git
# Out:
# /content
# Cloning into 'my-colab-project'...
# ...

# %%
# !ls /content
# Out:
# my-colab-project  sample_data

# %% [markdown]
# !git config --global user.name "aahanatyagi2007-ship-it"
# !git config --global user.email "aahanatyagi2007@gmail.com"
